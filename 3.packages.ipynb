# %%
npx react-native start

# %%
npx react-native run-android
npx react-native run-ios

# %%
npm outdated

# %%
npx npm-check-updates -u
npm install

# %%
npm install @aws-sdk/client-s3 @react-native-community/datetimepicker @react-native-community/geolocation @react-native-community/netinfo @react-native-community/slider @react-native-firebase/app @react-native-firebase/auth @react-native-firebase/crashlytics @react-native-firebase/messaging @react-native-firebase/remote-config @react-native-google-signin/google-signin @react-navigation/material-top-tabs react-native-razorpay date-fns lottie-react-native lucide-react-native react-native-agora react-native-asset react-native-audio-recorder-player react-native-collapsible react-native-compressor react-native-country-codes-picker react-native-create-thumbnail react-native-dropdown-picker react-native-fast-image react-native-geocoding react-native-gifted-charts react-native-google-mobile-ads react-native-google-places-autocomplete react-native-haptic-feedback react-native-inappbrowser-reborn react-native-keep-awake react-native-linear-gradient react-native-otp-textinput react-native-otp-verify react-native-push-notification react-native-qrcode-svg react-native-ratings react-native-read-more-text react-native-reanimated-carousel react-native-share react-native-shimmer-placeholder react-native-snap-carousel react-native-splash-screen react-native-svg react-native-toast-message react-native-track-player react-native-url-polyfill react-native-version-check react-native-view-shot react-native-vision-camera react-native-webview react-native-youtube-iframe react-redux redux rxjs timeago.js victory-native zego-express-engine-reactnative zustand --legacy-peer-deps
