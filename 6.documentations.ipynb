# %%
https://docs.agora.io/en/voice-calling/get-started/get-started-sdk?platform=react-native

https://github.com/react-native-community/cli

https://reactnative.dev/docs/getting-started-without-a-framework

# %%
https://pubscale.gitbook.io/offerwall-sdk/basic-integration/react-native

# %%
https://docs.page/invertase/react-native-google-mobile-ads

# %%
https://razorpay.com/docs/payments/payment-gateway/react-native-integration/standard?search-string=react%20native

https://razorpay.com/docs/payments/subscriptions/create/#subscription
