# %% [markdown]
# # android

# %%
#step1:
cd android
./gradlew assembleRelease
#This will generate a release APK at:



#step2: Install the APK on Your Device
adb install android/app/build/outputs/apk/release/app-release.apk


#
-Alternative: Use React Native CLI to Build and Install
-If you want to build and install in one step (sometimes works, sometimes not):
npx react-native run-android --mode=release
