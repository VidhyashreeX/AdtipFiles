# %%
npx @react-native-community/cli@latest init Adtip --skip-git-init
cd Adtip
npx react-native run-android
npx react-native doctor
rmdir /s /q .git

npm start
or
npx react-native start

# %%
adb devices

npm run android
npm run ios

# %%
#if:
npx @react-native-community/cli@latest init Adtip
rmdir /s /q .git

# %%
The error message indicates that your Android NDK installation at 27.1.12297006 is missing the source.properties file. This file is required for Gradle to recognize and use the NDK.

To resolve this issue, follow these steps:

1. Open Android Studio.
2. Go to Tools > SDK Manager.
3. In the SDK Manager, select the "SDK Tools" tab.
4. Check "NDK (Side by side)" and "CMake". Click "Apply" to install or update them.
5. After installation, verify that the folder 27.1.12297006 contains a source.properties file.
6. If the file is still missing, you can delete the ndk\27.1.12297006 folder and reinstall the NDK from the SDK Manager.
7. Once the NDK is properly installed, try running npx react-native run-android again.

Would you like step-by-step instructions for these actions, or should I add these troubleshooting steps to your project setup notebook?

# %%
C:\Users\poppo\Desktop\adtip\reactnative\adtip-reactnative\Adtip>npx react-native run-android
info Installing the app...

> Task :app:installDebug
Installing APK 'app-debug.apk' on 'I2301 - 13' for :app:debug
Installed on 1 device.

[Incubating] Problems report is available at: file:///C:/Users/poppo/Desktop/adtip/reactnative/adtip-reactnative/Adtip/android/build/reports/problems/problems-report.html

Deprecated Gradle features were used in this build, making it incompatible with Gradle 9.0.

You can use '--warning-mode all' to show the individual deprecation warnings and determine if they come from your own scripts or plugins.

For more on this, please refer to https://docs.gradle.org/8.13/userguide/command_line_interface.html#sec:command_line_warnings in the Gradle documentation.

BUILD SUCCESSFUL in 1m 2s
58 actionable tasks: 48 executed, 10 up-to-date
info Connecting to the development server...
8081
info Starting the app on "1665667316ZZZZZ"...
Starting: Intent { act=android.intent.action.MAIN cat=[android.intent.category.LAUNCHER] cmp=com.adtip/.MainActivity }

# %%
  Run instructions for Android:
    • Have an Android emulator running (quickest way to get started), or a device connected.
    • cd "C:\Users\poppo\Desktop\adtip\reactnative\adtip-reactnative\Adtip" && npx react-native run-android

  Run instructions for Windows:
    • See https://aka.ms/ReactNativeGuideWindows for the latest up-to-date instructions.

# %%
adb devices

npm run android
npm run ios

# %% [markdown]
# # tailwind setup

# %%
https://www.nativewind.dev/docs/getting-started/installation/frameworkless

# %%
npm install nativewind tailwindcss@^3.4.17 react-native-reanimated react-native-safe-area-context
npx tailwindcss init

/** @type {import('tailwindcss').Config} */
module.exports = {
  content: ["./src/**/*.{js,jsx,ts,tsx}"],
  presets: [require("nativewind/preset")],
  theme: {
    extend: {},
  },
  future: {
    hoverOnlyWhenSupported: true,
  },
  plugins: [],
};

or

/** @type {import('tailwindcss').Config} */
module.exports = {
  // NOTE: Update this to include the paths to all of your component files.
  content: ["./App.{js,jsx,ts,tsx}"],
  presets: [require("nativewind/preset")],
  theme: {
    extend: {},
  },
  plugins: [],
}

or

#Configure Tailwind: Update tailwind.config.js to scan your files for class names:
/** @type {import('tailwindcss').Config} */
module.exports = {
  content: [
    "./App.{js,jsx,ts,tsx}",
    "./src/**/*.{js,jsx,ts,tsx}", // Adjust based on your structure
  ],
  theme: {
    extend: {},
  },
  plugins: [],
};



#Set Up Babel: NativeWind requires a Babel plugin for processing. Install
npm install --save-dev babel-plugin-nativewind

# %%
#Update babel.config.js:
#Set Up Babel: NativeWind requires a Babel plugin for processing. Install
npm install --save-dev babel-plugin-nativewind

if already present (by default it will present no need to create or install)



#from:
const {getDefaultConfig, mergeConfig} = require('@react-native/metro-config');

/**
 * Metro configuration
 * https://reactnative.dev/docs/metro
 *
 * @type {import('@react-native/metro-config').MetroConfig}
 */
const config = {};

module.exports = mergeConfig(getDefaultConfig(__dirname), config);



#To:
const { getDefaultConfig, mergeConfig } = require("@react-native/metro-config");
const { withNativeWind } = require("nativewind/metro");
 
const config = mergeConfig(getDefaultConfig(__dirname), {
  /* your config */
});
 
module.exports = withNativeWind(config, { input: "./src/global.css" });

# %%
npx react-native start --reset-cache
npx react-native start
npx react-native doctor

# %% [markdown]
# # buidling in android:

# %%
Step-by-Step Process to Run on a Physical Device

Follow these steps to see your React Native app’s output on a physical mobile device:

    Enable USB Debugging on the Device:
        Android:
            Go to Settings > About Phone.
            Tap Build Number 7 times to enable Developer Options.
            Navigate to Settings > Developer Options (or System > Developer Options on some devices).
            Enable USB Debugging.
            Optionally, enable Stay awake for convenience during development.
        iOS (macOS only):
            No specific debugging toggle is required, but you’ll need to trust the computer when prompted.
            Ensure the device is running a supported iOS version (check compatibility with your Xcode version).
    Connect the Device to Your Computer:
        Plug your phone into your computer using a USB cable.
        Android:
            Install device drivers if prompted (Windows may require OEM drivers, downloadable from the device manufacturer’s website, e.g., Samsung, Xiaomi).
            Open a Command Prompt and run:
            bash

        adb devices
        This should list your device (e.g., <device-id> device). If empty or unauthorized, check USB debugging or reconnect the cable.
    iOS (macOS only):
        When prompted on the iOS device, tap Trust to allow the connection.
        Verify the device appears in Xcode under Window > Devices and Simulators.

Navigate to Your Project Directory: In Command Prompt, go to your project folder:
bash
cd C:\Users\poppo\Desktop\adtip\reactnative\adtip-app-reactnative\Adtip
Start the Metro Bundler: Metro is the JavaScript bundler for React Native, serving the app’s code to the device. Start it with:
bash
npm start

    This runs the Metro server, which the device will connect to for JavaScript updates.
    Keep this terminal open.

Run the App on the Device:

    Android: In a new Command Prompt window, ensure you’re in the project directory, then run:
    bash

npm run android

    This command builds the app, installs it on the connected device, and launches it.
    The app should appear on your phone, displaying the UI (e.g., the NativeWind-styled screen with <Text className="text-2xl font-bold text-blue-500">Hello, NativeWind!</Text>).
    If the NDK issue persists, ensure the source.properties file is present (as resolved in the previous response) before running this command.

# %% [markdown]
# Step-by-Step Process to Run on a Physical Device
#
# Follow these steps to see your React Native app’s output on a physical mobile device:
#
#     Enable USB Debugging on the Device:
#         Android:
#             Go to Settings > About Phone.
#             Tap Build Number 7 times to enable Developer Options.
#             Navigate to Settings > Developer Options (or System > Developer Options on some devices).
#             Enable USB Debugging.
#             Optionally, enable Stay awake for convenience during development.
#         iOS (macOS only):
#             No specific debugging toggle is required, but you’ll need to trust the computer when prompted.
#             Ensure the device is running a supported iOS version (check compatibility with your Xcode version).
#     Connect the Device to Your Computer:
#         Plug your phone into your computer using a USB cable.
#         Android:
#             Install device drivers if prompted (Windows may require OEM drivers, downloadable from the device manufacturer’s website, e.g., Samsung, Xiaomi).
#             Open a Command Prompt and run:
#             bash
#
#         adb devices
#         This should list your device (e.g., <device-id> device). If empty or unauthorized, check USB debugging or reconnect the cable.
#     iOS (macOS only):
#         When prompted on the iOS device, tap Trust to allow the connection.
#         Verify the device appears in Xcode under Window > Devices and Simulators.
#
# Navigate to Your Project Directory: In Command Prompt, go to your project folder:
# bash
# cd C:\Users\poppo\Desktop\adtip\reactnative\adtip-app-reactnative\Adtip
# Start the Metro Bundler: Metro is the JavaScript bundler for React Native, serving the app’s code to the device. Start it with:
# bash
# npm start
#
#     This runs the Metro server, which the device will connect to for JavaScript updates.
#     Keep this terminal open.
#
# Run the App on the Device:
#
#     Android: In a new Command Prompt window, ensure you’re in the project directory, then run:
#     bash
#
# npm run android
#
#     This command builds the app, installs it on the connected device, and launches it.
#     The app should appear on your phone, displaying the UI (e.g., the NativeWind-styled screen with <Text className="text-2xl font-bold text-blue-500">Hello, NativeWind!</Text>).
#     If the NDK issue persists, ensure the source.properties file is present (as resolved in the previous response) before running this command.
