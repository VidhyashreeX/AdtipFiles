# %%
npx @react-native-community/cli@latest init Adtip
cd Adtip
npm start

# %%
npm run android
npm run ios

# %% [markdown]
# # tailwind setup

# %% [markdown]
# npm install nativewind tailwindcss
# npx tailwindcss init
#
# Update tailwind.config.js:
# /** @type {import('tailwindcss').Config} */
# module.exports = {
#   content: [
#     "./App.{js,jsx,ts,tsx}",
#     "./src/**/*.{js,jsx,ts,tsx}", // Adjust based on your structure
#   ],
#   theme: {
#     extend: {},
#   },
#   plugins: [],
# };
#
#
# #Set Up Babel: NativeWind requires a Babel plugin for processing. Install:
# npm install --save-dev babel-plugin-nativewind
# #Update babel.config.js:
# module.exports = {
#   presets: ["module:@react-native/babel-preset"],
#   plugins: ["nativewind/babel"],
# };

# %%
Clear Metro Cache and Run: After setup, clear the cache to ensure changes take effect:
npx react-native start --reset-cache

# %%
npx react-native start
npx react-native doctor
adb devices
