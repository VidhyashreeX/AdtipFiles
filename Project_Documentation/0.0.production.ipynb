# %%
cd adtip-reactnative/Adtip
npx react-native run-android --variant=release

cd adtip-reactnative/Adtip/android
./gradlew bundleRelease

# %%
#optional:
cd adtip-reactnative/Adtip && npx react-native clean


#
cd adtip-reactnative/Adtip && cd android && ./gradlew clean
#
cd adtip-reactnative/Adtip/android && ./gradlew bundleRelease
