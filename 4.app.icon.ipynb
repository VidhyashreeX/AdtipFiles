# %%
Create react-native.config.js and Use react-native-asset

# %%
module.exports = {
  project: {
    ios: {},
    android: {},
  },
  assets: ['./assets/'],
};

# %%
Adtip/assets/icon.png

# %%
C:\Users\poppo\Desktop\adtip\reactnative\adtip-reactnative\Adtip>npx react-native-asset
info Linking ttf assets to iOS project 
WARN ERRGROUP Group 'Resources' does not exist in your Xcode project. We have created it automatically for you.
info Linking custom assets to iOS project 
info Linking ttf assets to Android project 
info Linking png assets to Android project 
info Linking jpg assets to Android project 
info Linking gif assets to Android project
info Linking custom assets to Android project
